# %%
import pandas as pd

df = pd.read_excel("/home/napbad/project/graduate_proj/core_model/dataset/data.xlsx")

print(df.columns)

with open("temp_columns.txt", "w"):
    for col in df.columns:
        print(col, file=open("temp_columns.txt", "a"))
# Out:
# Index(['7lesion_id', 'Label', 'PatientID', 'PatientID.1', '性别', '年龄', '高血压',
#        '心脏病', '糖尿病', '脑血管硬化',
#        ...
#        'wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis',
#        'wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis',
#        'wavelet-LLL_glszm_ZoneEntropy', 'wavelet-LLL_glszm_ZonePercentage',
#        'wavelet-LLL_glszm_ZoneVariance', 'wavelet-LLL_ngtdm_Busyness',
#        'wavelet-LLL_ngtdm_Coarseness', 'wavelet-LLL_ngtdm_Complexity',
#        'wavelet-LLL_ngtdm_Contrast', 'wavelet-LLL_ngtdm_Strength'],
#       dtype='str', length=2182)

# %%
import SimpleITK as sitk
import numpy as np

# %%
sitk_image = sitk.ReadImage("/home/napbad/PycharmProjects/Gradulate/uploads/5e51b88f4e1e4055b967647d1bdb237f_segmentation_probability.nii.gz")

np_image = sitk.GetArrayFromImage(sitk_image)

print(np_image.shape)
print(np_image.dtype)
print(np.mean(np_image))
print(np.max(np_image))
print(np.min(np_image))
